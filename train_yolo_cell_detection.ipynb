# %% [markdown]
# ### Train YOLO obj model on combined cell annotaions dataset to get cell_detector_model

# %%
from ultralytics import YOLO

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="60q1gKdq4vPi4tRgd831")
project = rf.workspace("digitizo").project("eldd-cell-annotations")
version = project.version(2)
dataset = version.download("yolov8")

# %%
# train12
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"

# runs\detect\train12 . took 2m . acc 0.98  . not better
model = YOLO('yolov8m.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=1024,
    rect=True, # to handle rectangle shapes
    batch=8,
    epochs=40,
    
    degrees =5.0,
    perspective=0.001,
    scale=0.0,
    shear=0.0,
    mosaic=0.0, # to not break geometry

    hsv_v = 0.2,
    hsv_s = 0.1,

    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"

# train54 . better than train3 . so it is the best . but in kaggle version is the bestest
model = YOLO('yolov8n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=640,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    # degrees =5.0,
    # perspective=0.001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.4,
    hsv_s = 0.7,
    hsv_h=0.015,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.243 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
                    cell         21       1842      0.887      0.966      0.989      0.729
        truncated_cell          4        312          1      0.989      0.995      0.889

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"

model = YOLO('yolov8n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=960,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    # degrees =5.0,
    # perspective=0.001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.4,
    hsv_s = 0.7,
    hsv_h=0.015,

    augment=True,
    patience=15,
    device=0,
)

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"


model = YOLO('yolo11n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=640,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    # degrees =5.0,
    # perspective=0.001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.4,
    hsv_s = 0.7,
    hsv_h=0.015,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"


model = YOLO('yolo11n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=960,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    # degrees =5.0,
    # perspective=0.001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.4,
    hsv_s = 0.7,
    hsv_h=0.015,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.253 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
model = YOLO('yolov8n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=640,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    degrees = 2.0,
    perspective=0.0001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.2,
    hsv_s = 0.5,
    hsv_h=0.015,

    # copy_paste=0.2,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
cell         21       1842      0.887      0.966      0.989      0.729
        truncated_cell          4        312          1      0.989      0.995      0.889

# %%
model = YOLO('yolov8n.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=960,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    degrees = 2.0,
    perspective=0.0001,
    # scale=0.0,
    # shear=0.0,
    mosaic=0.0, 
    # mixup=0.15,

    hsv_v = 0.2,
    hsv_s = 0.5,
    hsv_h=0.015,

    # copy_paste=0.2,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.253 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
model = YOLO('yolo11n.pt') # train83

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=960,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=100,
    
    degrees = 2.0,
    perspective=0.0001,
    # scale=0.0,
    # shear=0.0,
    mosaic=1.0, 
    mixup=0.15,

    hsv_v = 0.2,
    hsv_s = 0.5,
    hsv_h=0.015,

    # copy_paste=0.2,

    augment=True,
    patience=15,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction

det_model = AutoDetectionModel.from_pretrained(
    model_type='ultralytics',
    model_path=r'C:\Users\Rowan\Documents\Rowan\Yolo_test\runs\detect\train54\weights\best.pt',
    confidence_threshold=0.25,
    device="cuda:0"
)


result = get_sliced_prediction(
    r"C:\Users\Rowan\Documents\Rowan\all clean\DSC_1335.JPG",
    det_model,
    slice_height=640,
    slice_width=640,
    overlap_height_ratio=0.2,
    overlap_width_ratio=0.2,
    postprocess_type="NMS",
    postprocess_match_metric="IOS"
)

result.export_visuals(export_dir="sahi_output/", text_size=2, rect_th=2)
# Out:
# Performing prediction on 40 slices.

# %%
from ultralytics import YOLO
# Out:
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)
# c:\Users\Rowan\Documents\Rowan\Yolo_test\final_env_yolo\lib\site-packages\IPython\core\completerlib.py:150: UserWarning: This is now an optional IPython functionality, setting rootmodules_cache requires you to install the `pickleshare` library.
#   ip.db['rootmodules_cache'] = rootmodules_cache

# %%
import cv2

# %%
test_model = YOLO(r"C:\Users\Rowan\Documents\Rowan\Yolo_test\runs\detect\train54\weights\best.pt")

# test_model.predict(r"C:\Users\Rowan\Documents\Rowan\all clean\DSC_1335.JPG", project="sahi_output/", save=True, text_size=2,)
results = test_model(r"C:\Users\Rowan\Documents\Rowan\all clean\DSC_2242.JPG", iou=0.3, conf=0.25) 

# Get the annotated image with adjusted parameters
annotated_img = results[0].plot(line_width=3, font_size=15)

cv2.imwrite('sahi_output/save3.jpg', annotated_img)
# Out:
# image 1/1 C:\Users\Rowan\Documents\Rowan\all clean\DSC_2242.JPG: 640x448 155 cells, 3.1ms
# Speed: 1.5ms preprocess, 3.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
# True

# %%
# model2 = YOLO('yolov8m.pt') # was not much improved

# model2.train(
#     data=yaml_file,
#     imgsz=1024,
#     rect=True, # to handle rectangle shapes
#     batch=4,
#     nbs=64,
#     epochs=40,
    
#     degrees =5.0,
#     perspective=0.001,
#     scale=0.0,
#     shear=0.0,
#     mosaic=0.0, # to not break geometry

#     hsv_v = 0.2,
#     hsv_s = 0.1,

#     patience=15,
#     device=0,
# )
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
dataset_path = dataset.location
yaml_file = f"{dataset_path}/data.yaml"

#train3
# this is the best version . not anymore

# runs\detect\train3
model = YOLO('yolov8m.pt')

model.train(
    data=yaml_file,
    imgsz=960,
    rect=True, # to handle rectangle shapes
    batch=8,
    epochs=50,
    
    # degrees =5.0,
    # perspective=0.001,
    # scale=0.0,
    # shear=0.0,
    mosaic=0.0, # to not break geometry

    # hsv_v = 0.2,
    # hsv_s = 0.1,

    patience=20,
    workers=2,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"

# train52 . not that much

model = YOLO('yolov8m.pt')

model.train(
    data='ELDD---Cell-Annotations-2\data.yaml',
    imgsz=960,
    rect=True, # to handle rectangle shapes
    batch=8,
    epochs=50,
    
    mosaic=0.5,
    mixup=0.1,

    flipud=0.5,
    fliplr=0.5,
    degrees =10.0,
    hsv_v = 0.2,
    hsv_s = 0.1,

    patience=20,
    workers=2,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.243 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
# dataset_path = dataset.location
# yaml_file = f"{dataset_path}/data.yaml"

model = YOLO('yolov8m.pt')

model.train(
    data='ELDD---Cell-Annotations-2\data.yaml',
    imgsz=960,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=50,
    
    mosaic=0.5,
    mixup=0.1,

    flipud=0.5,
    fliplr=0.5,
    degrees =10.0,
    hsv_v = 0.2,
    hsv_s = 0.1,

    patience=20,
    workers=2,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.243 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.238  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
model = YOLO('yolov8m.pt')

model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",
    imgsz=1280,
    # rect=True, # to handle rectangle shapes
    batch=8,
    epochs=50,
    
    # degrees =5.0,
    # perspective=0.001,
    scale=0.1,
    shear=2.0,
    mosaic=0.5, # to not break geometry

    hsv_v = 0.4,
    hsv_s = 0.4,

    patience=10,
    workers=2,
    device=0,
)

# %%
from ultralytics import YOLOE
from ultralytics.models.yolo.yoloe import YOLOEPETrainer

# Initialize a detection model from a config
model = YOLOE("yoloe-11s.yaml")

# Load weights from a pretrained segmentation checkpoint (same scale)
model.load("yoloe-11s-seg.pt")

# Fine-tune on your detection dataset
results = model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",  # Detection dataset
    epochs=80,
    patience=10,
    imgsz=960,
    trainer=YOLOEPETrainer,  # <- Important: use detection trainer
)
# Out:
# ...
# Transferred 592/592 items from pretrained weights
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from ultralytics import YOLOE
from ultralytics.models.yolo.yoloe import YOLOEPETrainer

# Initialize a detection model from a config
model = YOLOE("yoloe-11s.yaml")

# Load weights from a pretrained segmentation checkpoint (same scale)
model.load("yoloe-11s-seg.pt")


# Fine-tune on your detection dataset
results = model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",  # Detection dataset
    epochs=80,
    patience=10,
    imgsz=960,
    batch=8,
    trainer=YOLOEPETrainer,  # <- Important: use detection trainer
)
# Out:
# Transferred 592/592 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
metrics = model.val(data=r"ELDD---Cell-Annotations-2\data.yaml", split='test', plots=True)

print(f"\n✅ Test mAP50: {metrics.box.map50:.3f}")
print(f"✅ Test mAP50-95: {metrics.box.map:.3f}")
# Out:
# Validate using the text prompt.
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# YOLOe-11s summary (fused): 104 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# File c:\Users\Rowan\Documents\Rowan\Yolo_test\final_env_yolo\lib\site-packages\ultralytics\data\base.py:176, in BaseDataset.get_img_files(self, img_path)
#
#     174             # F += [p.parent / x.lstrip(os.sep) for x in t]  # local to global path (pathlib)
#
#     175     else:
#
# --> 176         raise FileNotFoundError(f"{self.prefix}{p} does not exist")
#
#     177 im_files = sorted(x.replace("/", os.sep) for x in f if x.rpartition(".")[-1].lower() in IMG_FORMATS)
#
#
#
# FileNotFoundError: val: C:\Users\Rowan\Documents\Rowan\Yolo_test\ELDD---Cell-Annotations-2\test\images does not exist
#
#
#
# ...

# %%
from ultralytics import YOLOE
from ultralytics.models.yolo.yoloe import YOLOEPETrainer

# Initialize a detection model from a config
model = YOLOE("yoloe-11s.yaml")

# Load weights from a pretrained segmentation checkpoint (same scale)
model.load("yoloe-11s-seg.pt")


# Fine-tune on your detection dataset
results = model.train(
    data=r"ELDD---Cell-Annotations-2\data.yaml",  # Detection dataset
    epochs=80,
    patience=10,
    imgsz=960,
    batch=8,

    degrees=0.1,
    flipud=0.2,
    copy_paste=0.4,

    trainer=YOLOEPETrainer,  # <- Important: use detection trainer
)
# Out:
# Transferred 592/592 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %% [markdown]
# to be in script code

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

model.train(
    data=r"cell_separation_from_mixed_orig\final_yolo_datasets\vendor_1\data.yaml",
    epochs=50,
    imgsz=320,
    
    lr0=0.01,
    lrf=0.01,
    warmup_epochs=3,
    box=7.5,  # Increase box loss weight
    cls=0.5,  # Decrease cls loss if classes are imbalanced
    dfl=1.5,
    # fl_gamma=1.5,  # Focal loss
    mosaic=0.5,
    mixup=0.1,
    copy_paste=0.5,  # If available
    workers=2,
    
    patience=15,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.5 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data=r"cell_separation_from_mixed_orig\final_yolo_datasets\vendor_1\data.yaml",
    epochs=50,
    imgsz=320,
    
    lr0=0.01,
    lrf=0.01,
    warmup_epochs=3,
    box=7.5,  # Increase box loss weight
    cls=0.5,  # Decrease cls loss if classes are imbalanced
    dfl=1.5,
    # fl_gamma=1.5,  # Focal loss
    mosaic=0.0,
    mixup=0.1,
    copy_paste=0.5,  # If available
    workers=2,
    
    patience=15,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.5 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.245  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
class PVCellTestDataset(Dataset):
    def init(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []

        for label, subfolder in enumerate(["normal", "defective"]):
            folder_path = os.path.join(root_dir, subfolder)
            for fname in os.listdir(folder_path):
                if fname.lower().endswith((".png",".jpg")):
                    self.images.append(os.path.join(folder_path, fname))
                    self.labels.append(label)  # 0 = normal, 1 = defective

    def len(self):
        return len(self.images)

    def getitem(self, idx):
        img_path = self.images[idx]
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (256,256))
        if self.transform:
            img = self.transform(img)
        else:
            img = torch.tensor(img/255., dtype=torch.float32).unsqueeze(0)
        label = self.labels[idx]
        return img, label

# %%
# Out:
# image 1/1 C:\Users\Rowan\Documents\Rowan\Yolo_test\pv_cropped_ready_integ\test\images\2_jpg.rf.d889573b107487bcb1188ea5921dfaa9_cell44.jpg: 320x320 1 micro_crack, 5.5ms
# Speed: 5.6ms preprocess, 5.5ms inference, 17.5ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to C:\Users\Rowan\Documents\Rowan\Yolo_test\compare_final_cell_defect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'examined', 1: 'micro_crack', 2: 'crack', 3: 'low_cell', 4: 'low_string', 5: 'isolated_area', 6: 'contamination', 7: 'other_error'}
#  obb: None
#  orig_img: array([[[124, 124, 124],
#          [124, 124, 124],
#          [124, 124, 124],
#          ...,
#          [120, 120, 120],
#          [121, 121, 121],
#          [123, 123, 123]],
#
#         [[124, 124, 124],
#          [125, 125, 125],
#          [125, 125, 125],
#          ...,
#          [120, 120, 120],
# ...
